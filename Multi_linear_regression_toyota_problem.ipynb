# %% [markdown]
# # Toyota_Corolla Problem :
# ## --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Problem Statement :- Consider only the below columns and prepare a prediction model for predicting Price.
#
# ### Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]
#
#
#
# ##### Model -- model of the car
# ##### Price  -- Offer Price in EUROs
# ##### Age_08_04 -- Age in months as in August 2004
# ##### Mfg_Month -- Manufacturing month (1-12)
# ##### Mfg_Year	-- Manufacturing Year
# ##### KM -- Accumulated Kilometers on odometer
# ##### Fuel_Type	 -- Fuel Type (Petrol, Diesel, CNG)
# ##### HP -- Horse Power
# ##### Met_Color	 -- Metallic Color?  (Yes=1, No=0)
# ##### Color -- Color (Blue, Red, Grey, Silver, Black, etc.)
# ##### Automatic	-- Automatic ( (Yes=1, No=0)
# ##### cc -- Cylinder Volume in cubic centimeters
# ##### Doors -- Number of doors
# ##### Cylinders	-- Number of cylinders
# ##### Gears -- Number of gear positions
# ##### Quarterly_Tax -- Quarterly road tax in EUROs
# ##### Weight -- Weight in Kilograms
# ##### Mfr_Guarantee -- Within Manufacturer's Guarantee period  (Yes=1, No=0)
# ##### BOVAG_Guarantee -- BOVAG (Dutch dealer network) Guarantee  (Yes=1, No=0)
# ##### Guarantee_Period -- 	Guarantee period in months
# ##### ABS -- Anti-Lock Brake System (Yes=1, No=0)
# ##### Airbag_1 -- Driver_Airbag  (Yes=1, No=0)
# ##### Airbag_2 -- Passenger Airbag  (Yes=1, No=0)
# ##### Airco -- Airconditioning  (Yes=1, No=0)
# ##### Automatic_airco -- Automatic Airconditioning  (Yes=1, No=0)
# ##### Boardcomputer -- Boardcomputer  (Yes=1, No=0)
# ##### CD_Player -- CD Player  (Yes=1, No=0)
# ##### Central_Lock -- Central Lock  (Yes=1, No=0)
# ##### Powered_Windows -- Powered Windows  (Yes=1, No=0)
# ##### Power_Steering -- Power Steering  (Yes=1, No=0)
# ##### Radio -- Radio  (Yes=1, No=0)
# ##### Mistlamps	-- Mistlamps  (Yes=1, No=0)
# ##### Sport_Model -- Sport Model  (Yes=1, No=0)
# ##### Backseat_Divider -- Backseat Divider  (Yes=1, No=0)
# ##### Metallic_Rim --Metallic Rim  (Yes=1, No=0)
# ##### Radio_cassette -- Radio Cassette  (Yes=1, No=0)
# ##### Tow_Bar -- Tow Bar  (Yes=1, No=0)

# %% [markdown]
# ## 1) Import Libararies :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2) Import dataset :

# %%
toyota_dataset = pd.read_csv('ToyotaCorolla.csv',sep=',')
toyota_dataset
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3     �TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %% [markdown]
# ## 3) Data Understanding :

# %% [markdown]
# ### 3.1 Initial analysis :

# %%
toyota_dataset.shape
# Out:
# (1436, 38)

# %%
toyota_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
toyota_dataset.isna().sum()
# Out:
# Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Color               0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %%
toyota_dataset.dtypes
# Out:
# Id                   int64
# Model               object
# Price                int64
# Age_08_04            int64
# Mfg_Month            int64
# Mfg_Year             int64
# KM                   int64
# Fuel_Type           object
# HP                   int64
# Met_Color            int64
# Color               object
# Automatic            int64
# cc                   int64
# Doors                int64
# Cylinders            int64
# Gears                int64
# Quarterly_Tax        int64
# Weight               int64
# Mfr_Guarantee        int64
# BOVAG_Guarantee      int64
# Guarantee_Period     int64
# ABS                  int64
# Airbag_1             int64
# Airbag_2             int64
# Airco                int64
# Automatic_airco      int64
# Boardcomputer        int64
# CD_Player            int64
# Central_Lock         int64
# Powered_Windows      int64
# Power_Steering       int64
# Radio                int64
# Mistlamps            int64
# Sport_Model          int64
# ...

# %%
toyota_dataset.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           cc  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %% [markdown]
# ### 3.2 Data Preparation :

# %%
#Filtering the columns as per the given statement

toyota_dataset_1 = toyota_dataset[['Price','Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']]
toyota_dataset_1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
#Renaming the columns for the convenience

toyota_dataset_1.columns = ['price','age','km','hp','cc','doors','gears','quarterly_tax','weight']
toyota_dataset_1.head()
# Out:
#    price  age     km  hp    cc  doors  gears  quarterly_tax  weight
# 0  13500   23  46986  90  2000      3      5            210    1165
# 1  13750   23  72937  90  2000      3      5            210    1165
# 2  13950   24  41711  90  2000      3      5            210    1165
# 3  14950   26  48000  90  2000      3      5            210    1165
# 4  13750   30  38500  90  2000      3      5            210    1170

# %% [markdown]
# ### 3.3 Assumptions Check :

# %% [markdown]
# #### Assumption-1 : Linearity check

# %%
sns.pairplot(toyota_dataset_1)
plt.show()

# %% [markdown]
# #### OBSERVATION :- Linearity test "FAILED".

# %% [markdown]
# #### Assumption -2 : Normality check

# %%
sns.distplot(a = toyota_dataset_1['age'], hist = False)
plt.title('Normality check for age')
plt.show()

# %%
sns.distplot(a = toyota_dataset_1['km'], hist = False)
plt.title('Normality check for km')
plt.show()

# %%
sns.distplot(a = toyota_dataset_1['hp'], hist = False)
plt.title('Normality check for hp')
plt.show()

# %%
sns.distplot(a = toyota_dataset_1['cc'], hist = False)
plt.title('Normality check for cc')
plt.show()

# %%
sns.distplot(a = toyota_dataset_1['doors'], hist = False)
plt.title('Normality check for doors')
plt.show()

# %%
sns.distplot(a = toyota_dataset_1['gears'], hist = False)
plt.title('Normality check for gears')
plt.show()

# %%
sns.distplot(a = toyota_dataset_1['quarterly_tax'], hist = False)
plt.title('Normality check for quarterly_tax')
plt.show()

# %%
sns.distplot(a = toyota_dataset_1['weight'], hist = False)
plt.title('Normality check for weight')
plt.show()

# %% [markdown]
# #### OBSERVATION :- Normality Test "FAILED".

# %% [markdown]
# #### Assumption- 3 : Multi-Collinearity Test :

# %%
toyota_dataset_1_corr_matrix = toyota_dataset_1.corr().round(2)
toyota_dataset_1_corr_matrix
# Out:
#                price   age    km    hp    cc  doors  gears  quarterly_tax  \
# price           1.00 -0.88 -0.57  0.31  0.13   0.19   0.06           0.22
# age            -0.88  1.00  0.51 -0.16 -0.10  -0.15  -0.01          -0.20
# km             -0.57  0.51  1.00 -0.33  0.10  -0.04   0.02           0.28
# hp              0.31 -0.16 -0.33  1.00  0.04   0.09   0.21          -0.30
# cc              0.13 -0.10  0.10  0.04  1.00   0.08   0.01           0.31
# doors           0.19 -0.15 -0.04  0.09  0.08   1.00  -0.16           0.11
# gears           0.06 -0.01  0.02  0.21  0.01  -0.16   1.00          -0.01
# quarterly_tax   0.22 -0.20  0.28 -0.30  0.31   0.11  -0.01           1.00
# weight          0.58 -0.47 -0.03  0.09  0.34   0.30   0.02           0.63
#
#                weight
# price            0.58
# age             -0.47
# km              -0.03
# hp               0.09
# cc               0.34
# doors            0.30
# gears            0.02
# quarterly_tax    0.63
# ...

# %%
sns.heatmap(toyota_dataset_1_corr_matrix, annot = True)
plt.show()

# %% [markdown]
# #### Assumption - 4: Auto-Regression Check
#
# #### OBSERVATION :- Auto-Regression test "PASSED".

# %% [markdown]
# #### Assumption - 5 : Homoscadascity || Assumption - 6 : Zero Residual Mean test
#
# #### NOTE:- To be done after model testing.

# %% [markdown]
# ## 4) Model Building :

# %%
X = toyota_dataset_1.drop(labels ='price', axis = 1)
y = toyota_dataset_1[['price']]

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
scaled_X= std_scaler.fit_transform(X)
scaled_X
# Out:
# array([[-1.77196633, -0.57469494, -0.76804185, ..., -0.14042519,
#          2.98867967,  1.75856113],
#        [-1.77196633,  0.11745379, -0.76804185, ..., -0.14042519,
#          2.98867967,  1.75856113],
#        [-1.71818412, -0.71538641, -0.76804185, ..., -0.14042519,
#          2.98867967,  1.75856113],
#        ...,
#        [ 0.80957948, -1.37403589, -1.03513832, ..., -0.14042519,
#         -0.44078503, -1.09191497],
#        [ 0.75579727, -1.37670303, -1.03513832, ..., -0.14042519,
#         -0.44078503, -1.09191497],
#        [ 1.0784905 , -1.82784925,  0.5674405 , ..., -0.14042519,
#         -1.65690726,  0.78939926]])

# %%
scaled_X = pd.DataFrame(data=scaled_X,columns=['age','km','hp','cc','doors','gears','quarterly_tax','weight'])
scaled_X
# Out:
#            age        km        hp        cc     doors     gears  \
# 0    -1.771966 -0.574695 -0.768042  0.997419 -1.085139 -0.140425
# 1    -1.771966  0.117454 -0.768042  0.997419 -1.085139 -0.140425
# 2    -1.718184 -0.715386 -0.768042  0.997419 -1.085139 -0.140425
# 3    -1.610620 -0.547650 -0.768042  0.997419 -1.085139 -0.140425
# 4    -1.395491 -0.801028 -0.768042  0.997419 -1.085139 -0.140425
# ...        ...       ...       ...       ...       ...       ...
# 1431  0.702015 -1.279939 -1.035138 -0.652594 -1.085139 -0.140425
# 1432  0.863362 -1.321120 -1.035138 -0.652594 -1.085139 -0.140425
# 1433  0.809579 -1.374036 -1.035138 -0.652594 -1.085139 -0.140425
# 1434  0.755797 -1.376703 -1.035138 -0.652594 -1.085139 -0.140425
# 1435  1.078490 -1.827849  0.567440  0.054555  1.014941 -0.140425
#
#       quarterly_tax    weight
# 0          2.988680  1.758561
# 1          2.988680  1.758561
# 2          2.988680  1.758561
# 3          2.988680  1.758561
# ...

# %% [markdown]
# ## 5) Model Training :

# %%
from sklearn.linear_model import LinearRegression
linear_model_1 = LinearRegression()
linear_model_1.fit(scaled_X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## 6) Model  Testing :

# %%
y_predict = linear_model_1.predict(scaled_X)
y_predict
# Out:
# array([[16812.58050518],
#        [16272.35518581],
#        [16800.73245987],
#        ...,
#        [ 8454.29800682],
#        [ 8578.03812148],
#        [10402.43833285]])

# %% [markdown]
# ## 7) Model Evaluation :

# %%
error = y - y_predict
error
# Out:
#             price
# 0    -3312.580505
# 1    -2522.355186
# 2    -2850.732460
# 3    -1476.496731
# 4    -2472.419010
# ...           ...
# 1431 -1293.758297
# 1432  2553.661579
# 1433    45.701993
# 1434 -1328.038121
# 1435 -3452.438333
#
# [1436 rows x 1 columns]

# %% [markdown]
# ### ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Now checking for Homoscadascity and zero residual mean
#
# #### Assumption-5 : Homoscadascity check :

# %%
plt.scatter(x= scaled_X['age'],y=error)
plt.title('Homoscadascity check - Scaled age vs Error')
plt.xlabel('Scaled age')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x= scaled_X['km'],y=error)
plt.title('Homoscadascity check - Scaled km vs Error')
plt.xlabel('Scaled km')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x= scaled_X['hp'],y=error)
plt.title('Homoscadascity check - Scaled hp vs Error')
plt.xlabel('Scaled hp')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x= scaled_X['cc'],y=error)
plt.title('Homoscadascity check - Scaled cc vs Error')
plt.xlabel('Scaled cc')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x= scaled_X['doors'],y=error)
plt.title('Homoscadascity check - Scaled doors vs Error')
plt.xlabel('Scaled doors')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x= scaled_X['gears'],y=error)
plt.title('Homoscadascity check - Scaled gears vs Error')
plt.xlabel('Scaled gears')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x= scaled_X['quarterly_tax'],y=error)
plt.title('Homoscadascity check - Scaled quarterly tax vs Error')
plt.xlabel('Scaled quarterly tax')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x= scaled_X['weight'],y=error)
plt.title('Homoscadascity check - Scaled weight vs Error')
plt.xlabel('Scaled weight')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# #### OBSERVATION :- Homoscadascity check "FAILED".

# %% [markdown]
# #### Assumption- 6: Zero Residual Mean check

# %%
plt.scatter(x=y,y=y_predict)
plt.title('Zero Residual Mean- Actual output vs Predicted output')
plt.xlabel('Actual Output')
plt.ylabel('Predicted Output')
plt.show()

# %% [markdown]
# #### OBSERVATION :- Zero Residual Mean Check "FAILED".

# %% [markdown]
# #### -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
toyota_dataset_1.head()
# Out:
#    price  age     km  hp    cc  doors  gears  quarterly_tax  weight
# 0  13500   23  46986  90  2000      3      5            210    1165
# 1  13750   23  72937  90  2000      3      5            210    1165
# 2  13950   24  41711  90  2000      3      5            210    1165
# 3  14950   26  48000  90  2000      3      5            210    1165
# 4  13750   30  38500  90  2000      3      5            210    1170

# %%
X = toyota_dataset_1.drop(labels='price',axis = 1)

# %% [markdown]
# ### Model building :

# %%
import statsmodels.formula.api as smf

# %%
model_1 = smf.ols(formula = 'price ~ age + km + hp + cc + doors + gears + quarterly_tax + weight',data=toyota_dataset_1).fit()
model_1

# %%
y_predict_1 = model_1.predict(X)

# %% [markdown]
# #### Model Testing :

# %%
model_1.params
# Out:
# Intercept       -5573.106358
# age              -121.658402
# km                 -0.020817
# hp                 31.680906
# cc                 -0.121100
# doors              -1.616641
# gears             594.319936
# quarterly_tax       3.949081
# weight             16.958632
# dtype: float64

# %%
model_1.pvalues
# Out:
# Intercept         8.241949e-05
# age              3.354724e-288
# km                7.538439e-57
# hp                3.757218e-28
# cc                1.790902e-01
# doors             9.677716e-01
# gears             2.606549e-03
# quarterly_tax     2.619148e-03
# weight            2.048576e-52
# dtype: float64

# %%
model_1.tvalues
# Out:
# Intercept        -3.948666
# age             -46.511852
# km              -16.621622
# hp               11.241018
# cc               -1.344222
# doors            -0.040410
# gears             3.016007
# quarterly_tax     3.014535
# weight           15.879803
# dtype: float64

# %%
print('R2 Score          :',round(model_1.rsquared,5)) 
print('Adjusted R2 Score :',round(model_1.rsquared_adj,5))
print('AIC               :',round(model_1.aic,4))
print('BIC               :',round(model_1.bic,4))
# Out:
# R2 Score          : 0.86376
# Adjusted R2 Score : 0.863
# AIC               : 24769.0766
# BIC               : 24816.5032

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Fri, 26 Nov 2021   Prob (F-statistic):               0.00
# Time:                        20:18:46   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Model Deletion Diagnostic

# %% [markdown]
# #### Detecting Outliners and influencers

# %% [markdown]
# #### Cook's Distance

# %%
from statsmodels.graphics.regressionplots import influence_plot

# %%
model_1_influence = model_1.get_influence()
(c,_) = model_1_influence.cooks_distance

# %%
#Plotting influencers

fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(toyota_dataset_1)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#Checking the index and c value of influencer

(np.argmax(c),np.max(c))
# Out:
# (80, 79.52010624138055)

# %%
#High influence plot

influence_plot(model_1)
plt.show()

# %%
#Leverage cutoff value

k = toyota_dataset_1.shape[1]
n = toyota_dataset_1.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.020891364902506964

# %%
#From the above influence plot we can see that points at 80 is the major influencers

toyota_dataset_1[toyota_dataset_1.index.isin([80])]
# Out:
#     price  age     km   hp     cc  doors  gears  quarterly_tax  weight
# 80  18950   25  20019  110  16000      5      5            100    1180

# %% [markdown]
# #### Improving the model :

# %%
#remove the data points which are influencers and reasign the row number (reset_index())

toyota_dataset_1_new_1=toyota_dataset_1.drop(toyota_dataset_1.index[[80]],axis=0).reset_index()
toyota_dataset_1_new_1
# Out:
#       index  price  age     km   hp    cc  doors  gears  quarterly_tax  weight
# 0         0  13500   23  46986   90  2000      3      5            210    1165
# 1         1  13750   23  72937   90  2000      3      5            210    1165
# 2         2  13950   24  41711   90  2000      3      5            210    1165
# 3         3  14950   26  48000   90  2000      3      5            210    1165
# 4         4  13750   30  38500   90  2000      3      5            210    1170
# ...     ...    ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1430   1431   7500   69  20544   86  1300      3      5             69    1025
# 1431   1432  10845   72  19000   86  1300      3      5             69    1015
# 1432   1433   8500   71  17016   86  1300      3      5             69    1015
# 1433   1434   7250   70  16916   86  1300      3      5             69    1015
# 1434   1435   6950   76      1  110  1600      5      5             19    1114
#
# ...

# %%
model_2 = smf.ols(formula = 'price ~ age + km  + hp + cc + doors + gears + quarterly_tax + weight',data=toyota_dataset_1).fit()
model_2

# %%
print('R2 Score          :',round(model_2.rsquared,5)) 
print('Adjusted R2 Score :',round(model_2.rsquared_adj,5))
print('AIC               :',round(model_2.aic,4))
print('BIC               :',round(model_2.bic,4))
# Out:
# R2 Score          : 0.86376
# Adjusted R2 Score : 0.863
# AIC               : 24769.0766
# BIC               : 24816.5032

# %%
model_3 = smf.ols(formula = 'price ~ age + weight',data=toyota_dataset_1).fit()
model_3

# %%
print('R2 Score          :',round(model_3.rsquared,5)) 
print('Adjusted R2 Score :',round(model_3.rsquared_adj,5))
print('AIC               :',round(model_3.aic,4))
print('BIC               :',round(model_3.bic,4))
# Out:
# R2 Score          : 0.80507
# Adjusted R2 Score : 0.8048
# AIC               : 25271.5015
# BIC               : 25287.3103

# %%
model_4 = smf.ols(formula = 'price ~ age + weight + doors',data=toyota_dataset_1).fit()
model_4

# %%
print('R2 Score          :',round(model_4.rsquared,5)) 
print('Adjusted R2 Score :',round(model_4.rsquared_adj,5))
print('AIC               :',round(model_4.aic,4))
print('BIC               :',round(model_4.bic,4))
# Out:
# R2 Score          : 0.8051
# Adjusted R2 Score : 0.80469
# AIC               : 25273.318
# BIC               : 25294.3964

# %%
model_5 = smf.ols(formula = 'price ~ age + hp + km + doors',data=toyota_dataset_1).fit()
model_5

# %%
print('R2 Score          :',round(model_5.rsquared,5)) 
print('Adjusted R2 Score :',round(model_5.rsquared_adj,5))
print('AIC               :',round(model_5.aic,4))
print('BIC               :',round(model_5.bic,4))
# Out:
# R2 Score          : 0.81283
# Adjusted R2 Score : 0.8123
# AIC               : 25217.1964
# BIC               : 25243.5445

# %%
model_6 = smf.ols(formula = 'price ~ age + hp + km + doors + cc',data=toyota_dataset_1).fit()
model_6

# %%
print('R2 Score          :',round(model_6.rsquared,5)) 
print('Adjusted R2 Score :',round(model_6.rsquared_adj,5))
print('AIC               :',round(model_6.aic,4))
print('BIC               :',round(model_6.bic,4))
# Out:
# R2 Score          : 0.81576
# Adjusted R2 Score : 0.81511
# AIC               : 25196.5421
# BIC               : 25228.1598
